# %% [markdown]
# <a href="https://colab.research.google.com/github/Tehila-BD/cloud-computing/blob/main/MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Tue Apr  7 12:29:14 2026

# %%
time.sleep(5)
print(time.ctime())
# Out:
# Tue Apr  7 12:29:19 2026

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
# !pip install numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/Cloud_Computing - תרגולים"
# Out:
# 'Colab Notebooks'   students.txt

# %%
import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
x = [x for x in range (len(y))]

plt.plot(x, y, '-')
plt.fill_between(x, y, 200, where=(y > 195), facecolor = 'g', alpha = 0.6)

plt.title("Sample plot")
plt.show()

# %%
# @title "טופס ההשהיה שלי"
sleeptime = 2 #@param {type:"integer"}

# %%
import time
print(time.ctime())
time.sleep(sleeptime)
print(time.ctime())
# Out:
# Tue Apr  7 12:29:27 2026
# Tue Apr  7 12:29:29 2026

# %%
name = 'Tehila_BD' #@param {type:"string"}
print(name)
# Out:
# Tehila_BD

# %%
color = 'red' #@param ["red", "green", "blue"]
print(color)

# %%
#@title Date fields
date_input = '1999-01-08' #@param {type:"date"}
print(date_input)

# %%
# %%html
# <div style="background-color: #f0f0f0; padding: 20px; border-radius: 10px; border: 2px solid #4CAF50;">
#   <h1 style="color: #4CAF50;">היי תהילה!</h1>
#   <p style="font-size: 18px;">זה קוד HTML פשוט שרץ בתוך Google Colab.</p>
#   <button onclick="alert('איזה יופי, זה עובד!')">לחצי עליי</button>
# </div>
# Out:
# <div style="background-color: #f0f0f0; padding: 20px; border-radius: 10px; border: 2px solid #4CAF50;">
#   <h1 style="color: #4CAF50;">היי תהילה!</h1>
#   <p style="font-size: 18px;">זה קוד HTML פשוט שרץ בתוך Google Colab.</p>
#   <button onclick="alert('איזה יופי, זה עובד!')">לחצי עליי</button>
# </div>

# %%
from IPython.display import HTML

message = "בדיקת HTML מתוך פייתון"
html_code = f"""
<div style="color: blue; font-family: Arial;">
  <h3>{message}</h3>
</div>
"""

display(HTML(html_code))
# Out:
# <div style="color: blue; font-family: Arial;">
#   <h3>בדיקת HTML מתוך פייתון</h3>
# </div>

# %%
file_path = "/content/drive/MyDrive/Cloud_Computing - תרגולים/my_test_file.txt"

with open(file_path, "w") as f:
    f.write("היי! הקובץ הזה נוצר אוטומטית מתוך גוגל קולאב.\n")
    f.write(f"הוא נוצר בתאריך: {time.ctime()}")

print("הקובץ נשמר בהצלחה בדרייב!")
# Out:
# הקובץ נשמר בהצלחה בדרייב!

# %%
file_path = "/content/drive/MyDrive/Cloud_Computing - תרגולים/my_test_file.txt"

with open(file_path, "r") as f:
    content = f.read()

print("הנה מה שכתוב בתוך הקובץ:")
print("------------------------")
print(content)
# Out:
# הנה מה שכתוב בתוך הקובץ:
# ------------------------
# היי! הקובץ הזה נוצר אוטומטית מתוך גוגל קולאב.
# הוא נוצר בתאריך: Tue Apr  7 12:37:28 2026

# %%
with open('/content/drive/MyDrive/1.txt', 'w') as f:
    f.write("הצלחתי! הטקסט הזה נקרא מהדרייב בלחיצת כפתור.")
print("הקובץ 1.txt נוצר בהצלחה!")
# Out:
# הקובץ 1.txt נוצר בהצלחה!

# %%
import ipywidgets as widgets
from IPython.display import display

button = widgets.Button(
    description="לחצי לקריאת הקובץ",
    button_style='success',
    icon='download'
)
output = widgets.Output()


def on_button_clicked(b):
    output.clear_output()

    with output:
        try:
            with open('/content/drive/MyDrive/1.txt', 'r') as file:
                contents = file.read()
                print("--- תוכן הקובץ מ-Google Drive ---")
                print(contents)
        except FileNotFoundError:
            print("שגיאה: הקובץ 1.txt לא נמצא בנתיב המבוקש.")

button.on_click(on_button_clicked)
display(button, output)
# Out:
# Button(button_style='success', description='לחצי לקריאת הקובץ', icon='download', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
slider = widgets.IntSlider(value=5, max=10)
display(slider)
# Out:
# IntSlider(value=5, max=10)
